# %%
# %pip install torch torchvision matplotlib pillow
# Out:
# Requirement already satisfied: torch in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (2.8.0)
# Requirement already satisfied: torchvision in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (0.23.0)
# Requirement already satisfied: matplotlib in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (3.10.5)
# Requirement already satisfied: pillow in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (11.3.0)
# Requirement already satisfied: filelock in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from torch) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from torch) (2025.7.0)
# Requirement already satisfied: setuptools in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from torchvision) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\shashank s m\appdata\roaming\python\python313\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shashank s m\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\shashank s m\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shashank s m\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import shutil

# Paths
source_dir = r"D:\Downloads\Datasets\Wildlife_dataset\images\species_train"
extra_dir = r"D:\Downloads\Datasets\Wildlife_Species_Identification\Animal_dataset\train"
target_dir = r"D:\Downloads\Datasets\Imbalanced_dataset"

os.makedirs(target_dir, exist_ok=True)

# Get all class names from both datasets
all_classes = set(os.listdir(source_dir)) | set(os.listdir(extra_dir))

for cls in all_classes:
    images = []

    # Collect images from source dataset
    src_path = os.path.join(source_dir, cls)
    if os.path.isdir(src_path):
        images.extend([os.path.join(src_path, img) for img in os.listdir(src_path) if os.path.isfile(os.path.join(src_path, img))])

    # Collect images from extra dataset
    extra_path = os.path.join(extra_dir, cls)
    if os.path.isdir(extra_path):
        images.extend([os.path.join(extra_path, img) for img in os.listdir(extra_path) if os.path.isfile(os.path.join(extra_path, img))])

    if not images:
        print(f"⚠ Skipping class '{cls}' (no images found).")
        continue

    # Create class folder in target
    target_class_path = os.path.join(target_dir, cls)
    os.makedirs(target_class_path, exist_ok=True)

    # Copy with unique names (to avoid overwriting)
    for idx, img_path in enumerate(images):
        img_name = os.path.basename(img_path)
        new_name = f"{idx}_{img_name}"
        shutil.copy2(img_path, os.path.join(target_class_path, new_name))

    print(f"✅ {cls}: {len(images)} images copied")

print("\n🎯 Dataset merged successfully (kept imbalanced distribution)!")
# Out:
# ✅ Horse: 400 images copied
# ✅ Sea turtle: 239 images copied
# ✅ Chicken: 388 images copied
# ✅ leopardus_wiedii: 180 images copied
# ✅ Harbor seal: 240 images copied
# ✅ Lion: 208 images copied
# ✅ Canary: 113 images copied
# ✅ Otter: 75 images copied
# ✅ felis_silvestris: 108 images copied
# ✅ caracal_caracal: 101 images copied
# ✅ Spider: 856 images copied
# ✅ Whale: 287 images copied
# ✅ catopuma_temminckii: 2 images copied
# ✅ leptailurus_serval: 74 images copied
# ✅ Jellyfish: 457 images copied
# ✅ leopardus_guigna: 19 images copied
# ✅ Parrot: 421 images copied
# ✅ leopardus_emiliae: 5 images copied
# ✅ felis_nigripes: 4 images copied
# ✅ Fish: 835 images copied
# ✅ Fox: 148 images copied
# ✅ leopardus_geoffroyi: 147 images copied
# ✅ acinonyx_jubatus: 114 images copied
# ✅ Tick: 74 images copied
# ✅ Ostrich: 136 images copied
# ✅ elephas_maximus: 173 images copied
# ✅ Polar bear: 229 images copied
# ✅ Hedgehog: 80 images copied
# ✅ caracal_aurata: 16 images copied
# ✅ Owl: 406 images copied
# ✅ Cheetah: 132 images copied
# ✅ Hamster: 64 images copied
# ✅ Penguin: 377 images copied
# ✅ Scorpion: 80 images copied
# ✅ leopardus_tigrinus: 29 images copied
# ✅ leopardus_guttulus: 28 images copied
# ✅ Pig: 190 images copied
# ✅ Ladybug: 392 images copied
# ✅ Koala: 56 images copied
# ✅ Elephant: 155 images copied
# ✅ Kangaroo: 98 images copied
# ✅ Woodpecker: 171 images copied
# ✅ Worm: 128 images copied
# ✅ Brown bear: 108 images copied
# ✅ Cattle: 70 images copied
# ✅ Leopard: 123 images copied
# ✅ Sea lion: 188 images copied
# ✅ Magpie: 61 images copied
# ✅ Lynx: 80 images copied
# ✅ Shark: 303 images copied
# ✅ Giraffe: 298 images copied
# ✅ leopardus_jacobita: 2 images copied
# ✅ Centipede: 194 images copied
# ✅ felis_margarita: 1 images copied
# ✅ Duck: 542 images copied
# ✅ Goose: 289 images copied
# ✅ felis_chaus: 55 images copied
# ✅ Tortoise: 391 images copied
# ✅ Crab: 309 images copied
# ✅ Snail: 370 images copied
# ✅ felis_lybica: 51 images copied
# ✅ Squirrel: 367 images copied
# ✅ Dogs: 272 images copied
# ✅ Starfish: 248 images copied
# ✅ Crocodile: 108 images copied
# ✅ Panda: 91 images copied
# ✅ leopardus_pardalis: 684 images copied
# ✅ Swan: 233 images copied
# ✅ Lizard: 1200 images copied
# ✅ Mule: 61 images copied
# ✅ Zebra: 181 images copied
# ✅ Camel: 67 images copied
# ✅ Raccoon: 103 images copied
# ✅ Cats: 255 images copied
# ✅ Jaguar: 100 images copied
# ✅ Monkey: 770 images copied
# ✅ Moths and butterflies: 1429 images copied
# ✅ herpailurus_yagouaroundi: 262 images copied
# ✅ leopardus_pajeros: 10 images copied
# ✅ Rhinoceros: 214 images copied
# ✅ Goat: 202 images copied
# ✅ Sparrow: 475 images copied
# ✅ Bear: 87 images copied
# ✅ leopardus_garleppi: 5 images copied
# ✅ Tiger: 313 images copied
# ✅ Hippopotamus: 76 images copied
# ✅ Snake: 562 images copied
# ✅ Sheep: 99 images copied
# ✅ Frog: 588 images copied
# ✅ leopardus_colocola: 6 images copied
# ✅ Turkey: 86 images copied
# ✅ Caterpillar: 494 images copied
# ✅ Eagle: 719 images copied
# ✅ Butterfly: 1875 images copied
# ✅ Goldfish: 133 images copied
# ✅ Raven: 62 images copied
# ✅ leopardus_braccatus: 4 images copied
# ✅ Mouse: 151 images copied
# ✅ Deer: 327 images copied
# ✅ Rabbit: 216 images copied
#
# 🎯 Dataset merged successfully (kept imbalanced distribution)!

# %%
import os
import random
import shutil

dataset_dir = r"D:\Downloads\Datasets\Imbalanced_dataset"
output_dir = r"D:\Downloads\Datasets\Imbalanced_dataste_split"  # moved outside source folder

train_ratio = 0.7
val_ratio = 0.2
test_ratio = 0.1

os.makedirs(output_dir, exist_ok=True)
for split in ['train', 'val', 'test']:
    os.makedirs(os.path.join(output_dir, split), exist_ok=True)

for cls in os.listdir(dataset_dir):
    cls_path = os.path.join(dataset_dir, cls)

    # Skip if not a folder or is the output folder itself
    if not os.path.isdir(cls_path) or cls.lower() == "split_dataset":
        continue

    images = [f for f in os.listdir(cls_path) if os.path.isfile(os.path.join(cls_path, f))]
    random.shuffle(images)

    n_total = len(images)
    n_train = int(train_ratio * n_total)
    n_val = int(val_ratio * n_total)

    splits = {
        'train': images[:n_train],
        'val': images[n_train:n_train + n_val],
        'test': images[n_train + n_val:]
    }

    for split, split_images in splits.items():
        split_cls_dir = os.path.join(output_dir, split, cls)
        os.makedirs(split_cls_dir, exist_ok=True)
        for img in split_images:
            shutil.copy2(os.path.join(cls_path, img), os.path.join(split_cls_dir, img))

    print(f"✅ {cls}: {n_total} → Train:{n_train}, Val:{n_val}, Test:{len(images)-n_train-n_val}")

print("\n🎯 Dataset split into train/val/test successfully!")
# Out:
# ✅ acinonyx_jubatus: 114 → Train:79, Val:22, Test:13
# ✅ Bear: 87 → Train:60, Val:17, Test:10
# ✅ Brown bear: 108 → Train:75, Val:21, Test:12
# ✅ Butterfly: 1875 → Train:1312, Val:375, Test:188
# ✅ Camel: 67 → Train:46, Val:13, Test:8
# ✅ Canary: 113 → Train:79, Val:22, Test:12
# ✅ caracal_aurata: 16 → Train:11, Val:3, Test:2
# ✅ caracal_caracal: 101 → Train:70, Val:20, Test:11
# ✅ Caterpillar: 494 → Train:345, Val:98, Test:51
# ✅ catopuma_temminckii: 2 → Train:1, Val:0, Test:1
# ✅ Cats: 255 → Train:178, Val:51, Test:26
# ✅ Cattle: 70 → Train:49, Val:14, Test:7
# ✅ Centipede: 194 → Train:135, Val:38, Test:21
# ✅ Cheetah: 132 → Train:92, Val:26, Test:14
# ✅ Chicken: 388 → Train:271, Val:77, Test:40
# ✅ Crab: 309 → Train:216, Val:61, Test:32
# ✅ Crocodile: 108 → Train:75, Val:21, Test:12
# ✅ Deer: 327 → Train:228, Val:65, Test:34
# ✅ Dogs: 272 → Train:190, Val:54, Test:28
# ✅ Duck: 542 → Train:379, Val:108, Test:55
# ✅ Eagle: 719 → Train:503, Val:143, Test:73
# ✅ Elephant: 155 → Train:108, Val:31, Test:16
# ✅ elephas_maximus: 173 → Train:121, Val:34, Test:18
# ✅ felis_chaus: 55 → Train:38, Val:11, Test:6
# ✅ felis_lybica: 51 → Train:35, Val:10, Test:6
# ✅ felis_margarita: 1 → Train:0, Val:0, Test:1
# ✅ felis_nigripes: 4 → Train:2, Val:0, Test:2
# ✅ felis_silvestris: 108 → Train:75, Val:21, Test:12
# ✅ Fish: 835 → Train:584, Val:167, Test:84
# ✅ Fox: 148 → Train:103, Val:29, Test:16
# ✅ Frog: 588 → Train:411, Val:117, Test:60
# ✅ Giraffe: 298 → Train:208, Val:59, Test:31
# ✅ Goat: 202 → Train:141, Val:40, Test:21
# ✅ Goldfish: 133 → Train:93, Val:26, Test:14
# ✅ Goose: 289 → Train:202, Val:57, Test:30
# ✅ Hamster: 64 → Train:44, Val:12, Test:8
# ✅ Harbor seal: 240 → Train:168, Val:48, Test:24
# ✅ Hedgehog: 80 → Train:56, Val:16, Test:8
# ✅ herpailurus_yagouaroundi: 262 → Train:183, Val:52, Test:27
# ✅ Hippopotamus: 76 → Train:53, Val:15, Test:8
# ✅ Horse: 400 → Train:280, Val:80, Test:40
# ✅ Jaguar: 100 → Train:70, Val:20, Test:10
# ✅ Jellyfish: 457 → Train:319, Val:91, Test:47
# ✅ Kangaroo: 98 → Train:68, Val:19, Test:11
# ✅ Koala: 56 → Train:39, Val:11, Test:6
# ✅ Ladybug: 392 → Train:274, Val:78, Test:40
# ✅ Leopard: 123 → Train:86, Val:24, Test:13
# ✅ leopardus_braccatus: 4 → Train:2, Val:0, Test:2
# ✅ leopardus_colocola: 6 → Train:4, Val:1, Test:1
# ✅ leopardus_emiliae: 5 → Train:3, Val:1, Test:1
# ✅ leopardus_garleppi: 5 → Train:3, Val:1, Test:1
# ✅ leopardus_geoffroyi: 147 → Train:102, Val:29, Test:16
# ✅ leopardus_guigna: 19 → Train:13, Val:3, Test:3
# ✅ leopardus_guttulus: 28 → Train:19, Val:5, Test:4
# ✅ leopardus_jacobita: 2 → Train:1, Val:0, Test:1
# ✅ leopardus_pajeros: 10 → Train:7, Val:2, Test:1
# ✅ leopardus_pardalis: 684 → Train:478, Val:136, Test:70
# ✅ leopardus_tigrinus: 29 → Train:20, Val:5, Test:4
# ✅ leopardus_wiedii: 180 → Train:125, Val:36, Test:19
# ✅ leptailurus_serval: 74 → Train:51, Val:14, Test:9
# ✅ Lion: 208 → Train:145, Val:41, Test:22
# ✅ Lizard: 1200 → Train:840, Val:240, Test:120
# ✅ Lynx: 80 → Train:56, Val:16, Test:8
# ✅ Magpie: 61 → Train:42, Val:12, Test:7
# ✅ Monkey: 770 → Train:539, Val:154, Test:77
# ✅ Moths and butterflies: 1429 → Train:1000, Val:285, Test:144
# ✅ Mouse: 151 → Train:105, Val:30, Test:16
# ✅ Mule: 61 → Train:42, Val:12, Test:7
# ✅ Ostrich: 136 → Train:95, Val:27, Test:14
# ✅ Otter: 75 → Train:52, Val:15, Test:8
# ✅ Owl: 406 → Train:284, Val:81, Test:41
# ✅ Panda: 91 → Train:63, Val:18, Test:10
# ✅ Parrot: 421 → Train:294, Val:84, Test:43
# ✅ Penguin: 377 → Train:263, Val:75, Test:39
# ✅ Pig: 190 → Train:133, Val:38, Test:19
# ✅ Polar bear: 229 → Train:160, Val:45, Test:24
# ✅ Rabbit: 216 → Train:151, Val:43, Test:22
# ✅ Raccoon: 103 → Train:72, Val:20, Test:11
# ✅ Raven: 62 → Train:43, Val:12, Test:7
# ✅ Rhinoceros: 214 → Train:149, Val:42, Test:23
# ✅ Scorpion: 80 → Train:56, Val:16, Test:8
# ✅ Sea lion: 188 → Train:131, Val:37, Test:20
# ✅ Sea turtle: 239 → Train:167, Val:47, Test:25
# ✅ Shark: 303 → Train:212, Val:60, Test:31
# ✅ Sheep: 99 → Train:69, Val:19, Test:11
# ✅ Snail: 370 → Train:259, Val:74, Test:37
# ✅ Snake: 562 → Train:393, Val:112, Test:57
# ✅ Sparrow: 475 → Train:332, Val:95, Test:48
# ✅ Spider: 856 → Train:599, Val:171, Test:86
# ✅ Squirrel: 367 → Train:256, Val:73, Test:38
# ✅ Starfish: 248 → Train:173, Val:49, Test:26
# ✅ Swan: 233 → Train:163, Val:46, Test:24
# ✅ Tick: 74 → Train:51, Val:14, Test:9
# ✅ Tiger: 313 → Train:219, Val:62, Test:32
# ✅ Tortoise: 391 → Train:273, Val:78, Test:40
# ✅ Turkey: 86 → Train:60, Val:17, Test:9
# ✅ Whale: 287 → Train:200, Val:57, Test:30
# ✅ Woodpecker: 171 → Train:119, Val:34, Test:18
# ✅ Worm: 128 → Train:89, Val:25, Test:14
# ✅ Zebra: 181 → Train:126, Val:36, Test:19
#
# 🎯 Dataset split into train/val/test successfully!
